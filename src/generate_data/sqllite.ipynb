# %%
import sqlite3
import pandas as pd
con = sqlite3.connect('../assistant_flow/sales_data_insights/data/order_data.db')

# %%
# get schema of table `order_data`
query = "PRAGMA table_info(order_data)"
schema = pd.read_sql_query(query, con)
for i in range(len(schema)):
    print("# ", schema['name'][i], schema['type'][i])
# Out:
# #  Number_of_Orders INTEGER
# #  Sum_of_Order_Value_USD REAL
# #  Sum_of_Number_of_Items REAL
# #  Number_of_Orders_with_Discount INTEGER
# #  Sum_of_Discount_Percentage REAL
# #  Sum_of_Shipping_Cost_USD REAL
# #  Number_of_Orders_Returned INTEGER
# #  Number_of_Orders_Cancelled INTEGER
# #  Sum_of_Time_to_Fulfillment REAL
# #  Number_of_Orders_Repeat_Customers INTEGER
# #  Year INTEGER
# #  Month INTEGER
# #  Day INTEGER
# #  Date TIMESTAMP
# #  Day_of_Week INTEGER
# #  main_category TEXT
# #  sub_category TEXT
# #  product_type TEXT
# #  Region TEXT

# %%
# query to get the sum of number of orders, sum of order value, average order value, average shipping cost by month

query = """
    SELECT SUM(Number_of_Orders), 
           SUM(Sum_of_Order_Value_USD) as Total_Order_Value,
           SUM(Sum_of_Order_Value_USD)/SUM(Number_of_Orders) as Avg_Order_Value,
           SUM(Sum_of_Shipping_Cost_USD)/SUM(Number_of_Orders) as Avg_Shipping_Cost, 
           Region
    FROM order_data GROUP BY Region ORDER BY Total_Order_Value
"""
df = pd.read_sql_query(query, con)
df
# Out:
#    SUM(Number_of_Orders)  Total_Order_Value  Avg_Order_Value  \
# 0                  62542       1.090731e+06        17.439977
# 1                  61733       1.199403e+06        19.428885
# 2                  61200       1.340493e+06        21.903485
# 3                  61305       1.535948e+06        25.054205
# 4                  61230       1.789060e+06        29.218680
# 5                  61160       2.145344e+06        35.077561
#
#    Avg_Shipping_Cost         Region
# 0           7.497680  NORTH AMERICA
# 1           7.506037         EUROPE
# 2           7.499139   ASIA-PACIFIC
# 3           7.494681         AFRICA
# 4           7.483796    MIDDLE EAST
# 5           7.504288  SOUTH AMERICA

# %%
query = """
SELECT SUM(Sum_of_Order_Value_USD) as Revenue, Month, Year FROM order_data GROUP BY Month, Year ORDER BY Year, Month
"""
df = pd.read_sql_query(query, con)
df
# Out:
#           Revenue  Month  Year
# 0   646343.572673      1  2023
# 1   635823.665321      2  2023
# 2   786540.573459      3  2023
# 3   543494.939928      4  2023
# 4   632101.009288      5  2023
# 5   668956.290032      6  2023
# 6   498262.545868      7  2023
# 7   573845.261457      8  2023
# 8   589559.684640      9  2023
# 9   451324.589966     10  2023
# 10  510782.252097     11  2023
# 11  547556.999530     12  2023
# 12  414538.362211      1  2024
# 13  457296.952019      2  2024
# 14  497527.492448      3  2024
# 15  371925.684422      4  2024
# 16  275099.165766      5  2024

# %%
query = """
SELECT Day, SUM(Number_of_Orders) as Total_Orders
FROM order_data
WHERE Month = 1 AND Year = 2023
GROUP BY Day
HAVING SUM(Number_of_Orders) > 700
"""

df = pd.read_sql_query(query, con)
df
# Out:
#     Day  Total_Orders
# 0     1           717
# 1     2           740
# 2     3           719
# 3     4           730
# 4     5           724
# 5     6           711
# 6     7           709
# 7     8           723
# 8     9           719
# 9    10           731
# 10   11           722
# 11   12           723
# 12   13           728
# 13   14           726
# 14   15           721
# 15   16           719
# 16   17           729
# 17   18           719
# 18   19           733
# 19   20           724
# 20   21           714
# 21   22           719
# 22   23           721
# 23   24           724
# 24   25           712
# 25   26           738
# 26   27           723
# 27   28           721
# 28   29           712
# 29   30           732
# 30   31           724

# %%
# query to get the sum of number of orders, sum of order value, average order value, average shipping cost by month
query = """
    SELECT SUM(Number_of_Orders), 
           SUM(Sum_of_Order_Value_USD),
           SUM(Sum_of_Order_Value_USD)/SUM(Number_of_Orders) as Avg_Order_Value,
           SUM(Sum_of_Shipping_Cost_USD)/SUM(Number_of_Orders) as Avg_Shipping_Cost, 
           Month
    FROM order_data GROUP BY Month
"""
df = pd.read_sql_query(query, con)
df
# Out:
#     SUM(Number_of_Orders)  SUM(Sum_of_Order_Value_USD)  Avg_Order_Value  \
# 0                   45356                 1.060882e+06        23.390112
# 1                   41450                 1.093121e+06        26.372029
# 2                   45058                 1.284068e+06        28.498115
# 3                   44421                 9.154206e+05        20.607835
# 4                   37230                 9.072002e+05        24.367450
# 5                   21790                 6.689563e+05        30.700151
# 6                   22530                 4.982625e+05        22.115515
# 7                   22498                 5.738453e+05        25.506501
# 8                   21766                 5.895597e+05        27.086267
# 9                   22698                 4.513246e+05        19.883892
# 10                  21814                 5.107823e+05        23.415341
# 11                  22559                 5.475570e+05        24.272219
#
#     Avg_Shipping_Cost  Month
# 0            7.481863      1
# 1            7.487434      2
# 2            7.508766      3
# 3            7.488470      4
# 4            7.490166      5
# 5            7.528267      6
# 6            7.500898      7
# 7            7.510961      8
# 8            7.495198      9
# 9            7.517288     10
# 10           7.497781     11
# 11           7.492172     12

# %%
query = """
SELECT SUM(Number_of_Orders) FROM order_data WHERE main_category = 'APPAREL' AND sub_category = "MEN'S CLOTHING" AND Month = 5 AND Year = 2024
"""
df = pd.read_sql_query(query, con)
df
# Out:
#    SUM(Number_of_Orders)
# 0                    665

# %%
con.close()

# %%
import json
df  = pd.read_csv('test_data.csv')
df
# Out:
#                                              question  \
# 0   what are the orders for women's clothing by da...
# 1       query for all the values for the product_type
# 2   what was the total revenue in May 2024 by prod...
# 3   what was the total revenue in May 2024 by sub_...
# 4   show the total revenue by day and sub_category...
# 5      query for the month with the strongest revenue
# 6             query for all the values for the Region
# 7      query for all the values for the main_category
# 8          what is the average sale value for January
# 9   query for the total revenue in January 2024 fo...
# 10  show the sales revenue by main_category "Campi...
# 11  show the revenue grouped by sub_category and p...
# 12  how many orders of Travel pillows were process...
# 13  how many orders of Travel pillows were process...
# 14  what was the total revenue in January 2024 by ...
# 15  what was the total revenue in January 2024 by ...
# 16                    show the 2023 sales by category
# 17  what was the total revenue in 2023 by main_cat...
# 18  what was the total revenue in 2023 by main_cat...
# 19       what was the total revenue in 2023 by region
# 20  what was the total revenue in 2023 by main_cat...
# 21              show the total sales revenue by month
# 22  what was the total revenue in the current mont...
# 23  how many orders were made for travel pillows t...
# 24  what was the total number of orders in May 202...
# 25  what was the total revenue in February 2024 by...
# 26      query for all the values for the sub_category
# 27  query for all distinct values for main_categor...
# 28  query for all the values for sub_category and ...
# 29  what was the total number of items sold for pr...
# 30  how many orders in the main category of "appar...
# 31  how many orders did we have in women's clothin...
# 32  query for all the values for the product_type ...
# 33  what is the sum of items by Region, product_ty...
# 34  query for all the values for product_type wher...
# 35  query for all the values for product_type wher...
# 36  what was the total revenue for product_type = ...
# 37      what was the total revenue in May 2024 by day
# 38               what was the total revenue in EUROPE
# 39    what was the total revenue in Q1 2024 by region
# 40  query for all the values for the product_type ...
# 41  query for all the values for the sub_category ...
# 42  what is the sum of items by product_type where...
# 43  on which day in May 2024 did we sell the most ...
# 44  show the total sales of product_type "TRAVEL P...
# 45  how many orders of Travel pillows were process...
# 46  what was the total revenue in 2023 by main_cat...
# 47      what was the total revenue in May 2024 by day
#
#                                                 query
# 0   SELECT SUM(Number_of_Orders)\nFROM order_data\...
# 1       SELECT DISTINCT product_type\nFROM order_data
# 2   SELECT SUM(Sum_of_Order_Value_USD) as Total_Re...
# 3   SELECT SUM(Sum_of_Order_Value_USD) as Total_Re...
# 4   SELECT Day, sub_category, SUM(Sum_of_Order_Val...
# 5   SELECT SUM(Sum_of_Order_Value_USD) as Total_Re...
# 6             SELECT DISTINCT Region\nFROM order_data
# 7      SELECT DISTINCT main_category\nFROM order_data
# 8   SELECT SUM(Sum_of_Order_Value_USD) / SUM(Numbe...
# 9   SELECT SUM(Sum_of_Order_Value_USD)\nFROM order...
# 10  SELECT main_category, \n       SUM(Sum_of_Orde...
# 11  SELECT sub_category,\n       product_type,\n  ...
# 12  SELECT SUM(Number_of_Orders) \nFROM order_data...
# 13  SELECT SUM(Number_of_Orders)\nFROM order_data\...
# 14  SELECT SUM(Sum_of_Order_Value_USD) as Total_Re...
# 15  SELECT SUM(Sum_of_Order_Value_USD) as Total_Re...
# 16  SELECT main_category, \n       SUM(Number_of_O...
# 17  SELECT SUM(Sum_of_Order_Value_USD) as Total_Re...
# 18  SELECT SUM(Sum_of_Order_Value_USD) as Total_Re...
# 19  SELECT SUM(Sum_of_Order_Value_USD) as Total_Re...
# 20  SELECT SUM(Sum_of_Order_Value_USD) as Total_Re...
# 21  SELECT SUM(Sum_of_Order_Value_USD) as Total_Sa...
# 22  SELECT SUM(Sum_of_Order_Value_USD),\n       pr...
# 23  SELECT SUM(Number_of_Orders), \n       Region\...
# 24  SELECT Day, SUM(Number_of_Orders) as Total_Ord...
# 25  SELECT Day, SUM(Sum_of_Order_Value_USD) as Tot...
# 26      SELECT DISTINCT sub_category\nFROM order_data
# 27  SELECT DISTINCT main_category, sub_category\nF...
# 28  SELECT DISTINCT sub_category, product_type\nFR...
# 29  SELECT SUM(Sum_of_Number_of_Items) \nFROM orde...
# 30  SELECT SUM(Number_of_Orders) \nFROM order_data...
# 31  SELECT SUM(Number_of_Orders) \nFROM order_data...
# 32  SELECT DISTINCT product_type\nFROM order_data\...
# 33  SELECT SUM(Sum_of_Number_of_Items) as Total_It...
# 34  SELECT DISTINCT product_type\nFROM order_data\...
# 35  SELECT DISTINCT product_type\nFROM order_data\...
# 36  SELECT SUM(Sum_of_Order_Value_USD) as Total_Re...
# 37  SELECT SUM(Sum_of_Order_Value_USD) as Total_Re...
# 38  SELECT SUM(Sum_of_Order_Value_USD) as Total_Re...
# 39  SELECT SUM(Sum_of_Order_Value_USD) as Total_Re...
# 40  SELECT DISTINCT product_type\nFROM order_data\...
# 41  SELECT DISTINCT sub_category\nFROM order_data\...
# 42  SELECT SUM(Sum_of_Number_of_Items),\n       pr...
# 43  SELECT Day\nFROM order_data\nWHERE Month = 5 \...
# 44  SELECT Day, SUM(Sum_of_Order_Value_USD) as Tot...
# 45  SELECT SUM(Number_of_Orders)\nFROM order_data\...
# 46  SELECT main_category, \n       SUM(Sum_of_Orde...
# 47  SELECT SUM(Sum_of_Order_Value_USD) as Total_Re...
